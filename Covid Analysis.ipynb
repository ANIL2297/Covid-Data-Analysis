# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import matplotlib.colors as mcolors

# %%
age = pd.read_csv('AgeGroupDetails.csv')
hsptl = pd.read_csv('HospitalBedsIndia.csv')
icmr = pd.read_csv('ICMRTestingLabs.csv')
testing = pd.read_csv('StatewiseTestingDetails.csv')
individual = pd.read_csv('IndividualDetails.csv')

# %%
age.head()
# Out:
#    Sno AgeGroup  TotalCases Percentage
# 0    1      0-9          22      3.18%
# 1    2    10-19          27      3.90%
# 2    3    20-29         172     24.86%
# 3    4    30-39         146     21.10%
# 4    5    40-49         112     16.18%

# %%
def plot_pie_charts(x, y, title):
    c = random.choices(list(mcolors.CSS4_COLORS.values()),k = 10)
    plt.figure(figsize=(10,15))
    plt.title(title, size=20)
    plt.pie(y, colors = c)
    plt.legend(x,loc="best")
    plt.show()

# %%
plot_pie_charts(age['AgeGroup'], age['TotalCases'], 'Age distribution')

# %%
def plot_bar_graphs(x, y, title):
    plt.figure(figsize=(20, 12))
    plt.barh(x, y)
    plt.title(title, size=20)
    plt.xticks(size=15)
    plt.yticks(size=20)
    plt.show()
hsptl = hsptl.drop(hsptl.index[36])

# %%
plot_bar_graphs(hsptl['State/UT'], hsptl['NumRuralHospitals_NHP18'], 'No of Rural Hospitals in different regions')

# %%
plot_bar_graphs(hsptl['State/UT'], hsptl['NumRuralBeds_NHP18'], 'No of Rural Beds in different regions')

# %%
plot_bar_graphs(hsptl['State/UT'], hsptl['NumUrbanHospitals_NHP18'], 'No of Urban Hospitals in different regions')

# %%
plot_bar_graphs(hsptl['State/UT'], hsptl['NumUrbanBeds_NHP18'], 'No of Urban Beds in different regions')

# %%
plot_bar_graphs(df2['State/UT'], df2['TotalPublicHealthFacilities_HMIS'], '# of Public Health Facilities in different regions')

# %%
 plot_bar_graphs(hsptl['State/UT'], hsptl['NumPublicBeds_HMIS'], 'No of Public Beds in different regions')

# %%
icmr['state'].value_counts()
# Out:
# Maharashtra                                 39
# Tamil Nadu                                  26
# Telangana                                   19
# Delhi                                       18
# Uttar Pradesh                               17
# Karnataka                                   17
# Gujarat                                     14
# West Bengal                                 13
# Kerala                                      12
# Haryana                                     11
# Madhya Pradesh                              10
# Rajasthan                                    9
# Odisha                                       7
# Andhra Pradesh                               7
# Assam                                        6
# Bihar                                        6
# Punjab                                       5
# Jammu and Kashmir                            4
# Uttarakhand                                  3
# Jharkhand                                    3
# ...

# %%
sns.set(rc={'figure.figsize':(30,10)})
sns.countplot(x = "state", data = icmr)

# %%
sns.countplot(x = "type", data = icmr)

# %%
testing_sort =testing.sort_values(by = 'TotalSamples', ascending=False).head()
testing_sort.head()
# Out:
#             Date       State  TotalSamples   Negative  Positive
# 1068  2020-05-20  Tamil Nadu      360068.0  3346311.0   13191.0
# 1067  2020-05-19  Tamil Nadu      348174.0   334839.0   12448.0
# 1066  2020-05-18  Tamil Nadu      337841.0   325546.0   11760.0
# 1065  2020-05-17  Tamil Nadu      326720.0   315019.0   11224.0
# 1064  2020-05-16  Tamil Nadu      313639.0   302523.0   10585.0

# %%
testing_sort1 =testing.sort_values(by = 'TotalSamples', ascending=True).head()
testing_sort1.head()
# Out:
#            Date     State  TotalSamples  Negative  Positive
# 765  2020-04-07   Mizoram          58.0       0.0       1.0
# 764  2020-04-06   Mizoram          58.0       0.0       1.0
# 804  2020-04-06  Nagaland          60.0      47.0       0.0
# 806  2020-04-11  Nagaland          70.0      70.0       0.0
# 805  2020-04-10  Nagaland          70.0      69.0       0.0

# %%
individual['gender'].isna().sum()
# Out:
# 22577

# %%
individual['gender'].value_counts()
# Out:
# M    3547
# F    1766
# Name: gender, dtype: int64

# %%
sns.countplot(x = "gender", data = individual)

# %%
individual['detected_district'].value_counts()
# Out:
# Mumbai               2687
# Ahmedabad            2181
# Indore               1036
# Jaipur                808
# Pune                  680
#                      ...
# Lakhimpur               1
# South 24 Parganas       1
# Dohad                   1
# Sirmaur                 1
# Golaghat                1
# Name: detected_district, Length: 449, dtype: int64

# %%
sns.countplot(x = "detected_state", data = individual)

# %%
sns.countplot(x = "current_status", data = individual)
